# %% [markdown]
# Build a model to detect fraudulent credit card transactions. Use adataset containing information about credit card transactions, andexperiment with algorithms like Logistic Regression, Decision Trees,or Random Forests to classify transactions as fraudulent orlegitimate.

# %%
import pandas as pd

X = pd.read_csv('fraudTrain.csv',engine='python',error_bad_lines=False)
y = pd.read_csv('fraudTest.csv')
# Out:
# <ipython-input-126-fa5c6ca8517b>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   X = pd.read_csv('fraudTrain.csv',engine='python',error_bad_lines=False)

# %%
X.shape
# Out:
# (918328, 23)

# %%
y.shape
# Out:
# (555719, 23)

# %%
X.head().transpose()
# Out:
#                                                       0  \
# Unnamed: 0                                            0
# trans_date_trans_time               2019-01-01 00:00:18
# cc_num                               2703186189652095.0
# merchant                     fraud_Rippin, Kub and Mann
# category                                       misc_net
# amt                                                4.97
# first                                          Jennifer
# last                                              Banks
# gender                                                F
# street                                   561 Perry Cove
# city                                     Moravian Falls
# state                                                NC
# zip                                             28654.0
# lat                                             36.0788
# long                                           -81.1781
# city_pop                                         3495.0
# ...

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
X.describe()
# Out:
#          Unnamed: 0        cc_num            amt            zip  \
# count  918328.00000  9.183270e+05  918327.000000  918327.000000
# mean   459163.50000  4.166811e+17      70.251291   48799.711225
# std    265098.60334  1.308242e+18     161.391022   26905.738398
# min         0.00000  6.041621e+10       1.000000    1257.000000
# 25%    229581.75000  1.800400e+14       9.640000   26237.000000
# 50%    459163.50000  3.520550e+15      47.440000   48174.000000
# 75%    688745.25000  4.642255e+15      83.070000   72042.000000
# max    918327.00000  4.992346e+18   28948.900000   99783.000000
#
#                  lat           long      city_pop     unix_time  \
# count  918327.000000  918327.000000  9.183270e+05  9.183270e+05
# mean       38.534055     -90.228488  8.911297e+04  1.342772e+09
# std         5.076314      13.768725  3.025284e+05  9.032144e+06
# min        20.027100    -165.672300  2.300000e+01  1.325376e+09
# 25%        34.620500     -96.798000  7.430000e+02  1.335433e+09
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918328 entries, 0 to 918327
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             918328 non-null  int64
#  1   trans_date_trans_time  918327 non-null  object
#  2   cc_num                 918327 non-null  float64
#  3   merchant               918327 non-null  object
#  4   category               918327 non-null  object
#  5   amt                    918327 non-null  float64
#  6   first                  918327 non-null  object
#  7   last                   918327 non-null  object
#  8   gender                 918327 non-null  object
#  9   street                 918327 non-null  object
#  10  city                   918327 non-null  object
#  11  state                  918327 non-null  object
#  12  zip                    918327 non-null  float64
#  13  lat                    918327 non-null  float64
# ...

# %%
X.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    1
# cc_num                   1
# merchant                 1
# category                 1
# amt                      1
# first                    1
# last                     1
# gender                   1
# street                   1
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
X.dropna(inplace=True)

# %%
X.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
train = pd.DataFrame(X,columns=['cc_num','amt','zip','lat', 'long',
                                'city_pop', 'unix_time','merch_lat', 'merch_long', 'is_fraud'])
test = pd.DataFrame(y,columns=['cc_num','amt','zip','lat', 'long',
                               'city_pop', 'unix_time','merch_lat', 'merch_long', 'is_fraud'])

# %%
train.shape
# Out:
# (918327, 10)

# %%
test.shape
# Out:
# (555719, 10)

# %%
train.head()
# Out:
#          cc_num     amt      zip      lat      long  city_pop     unix_time  \
# 0  2.703186e+15    4.97  28654.0  36.0788  -81.1781    3495.0  1.325376e+09
# 1  6.304233e+11  107.23  99160.0  48.8878 -118.2105     149.0  1.325376e+09
# 2  3.885949e+13  220.11  83252.0  42.1808 -112.2620    4154.0  1.325376e+09
# 3  3.534094e+15   45.00  59632.0  46.2306 -112.1138    1939.0  1.325376e+09
# 4  3.755342e+14   41.96  24433.0  38.4207  -79.4629      99.0  1.325376e+09
#
#    merch_lat  merch_long  is_fraud
# 0  36.011293  -82.048315       0.0
# 1  49.159047 -118.186462       0.0
# 2  43.150704 -112.154481       0.0
# 3  47.034331 -112.561071       0.0
# 4  38.674999  -78.632459       0.0

# %%
X_train = train.drop(['is_fraud'], axis=1)
y_train = train['is_fraud']

X_test = test.drop(['is_fraud'], axis=1)
y_test = test['is_fraud']

# %%
X_train.shape
# Out:
# (918327, 9)

# %%
X_test.shape
# Out:
# (555719, 9)

# %%
y_train.shape
# Out:
# (918327,)

# %%
y_test.shape
# Out:
# (555719,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{classification_rep}")
# Out:
# Accuracy: 0.9956650753348365
# Confusion Matrix:
# [[553310    264]
#  [  2145      0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.00      0.00      0.00      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.50      0.50      0.50    555719
# weighted avg       0.99      1.00      0.99    555719
